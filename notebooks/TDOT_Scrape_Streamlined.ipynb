# %%
import pandas as pd
import requests
import datetime
from bs4 import BeautifulSoup
import re
from math import ceil
from tqdm.notebook import tqdm
import glob

# %%
headers = {'cookie': 'searchTab=0; MS2Session=aqrzeguifhyoqg4qt5oiz4kd; __utmc=1; __utmz=1.1639408576.13.5.utmcsr=tn.gov|utmccn=(referral)|utmcmd=referral|utmcct=/; MS2Session_TMS=cjchgoe0y2nmm2h1ot2sfctm; __utma=1.740782077.1638412679.1639726387.1639752588.30; __utmt=1; __utmb=1.10.10.1639752588'}

# %%
# Get the local_id for a given offset
offset = 0

URL = f'https://tdot.public.ms2soft.com/tcds/tdetail.asp?offset={offset}'

response = requests.get(URL, headers = headers)

local_id = pd.read_html(response.text)[7].loc[0,1]
local_id
# Code to grab lat/lng probably using BeautifulSoup
# Out:
# '11000001'

# %%
# Get the first page of results
pg = 1

URL = f'https://tdot.public.ms2soft.com/tcds/ajax/tcds_tdetail_aadt.asp?offset={offset}&agency_id=295&local_id={local_id}&page_type=&pg={pg}&ajax_time=1639668768124'

response = requests.get(URL, headers = headers)
aadt_table = pd.read_html(response.text)[0]
aadt_table
## Code here to iterate through all of the pages and likely export the results
# Out:
#                                                    0  \
# 0  AADT  AADT Calculation  AADT = VOL x SF x AF A...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                          1-5 of 36
#
#                                                    1  \
# 0  AADT  AADT Calculation  AADT = VOL x SF x AF A...
# 1                                               Year
# 2                                               2020
# 3                                               2019
# 4                                               2018
# 5                                               2017
# 6                                               2016
# 7                                          1-5 of 36
#
# ...

# %%
ceil(int(aadt_table.iloc[7,0].split()[2]) / 5)
# Out:
# 8

# %%
# tcds.detail_aadt
# findd url
# find cookie

# %%
cheatham = []

# %%
aadt_table
# Out:
#                                                    0
# 0  DIV.banner_icon {float: right; font-size: 9px;...

# %%
str(13).zfill(3)
# Out:
# '013'

# %%
cheatham = []
for offset in tqdm(range(33)):
    URL = f'https://tdot.public.ms2soft.com/tcds/tdetail.asp?offset={offset}'
    r = requests.get(URL, headers = headers)
    local_id = pd.read_html(r.text)[7].loc[0,1]
    pg = 1
    URL = f'https://tdot.public.ms2soft.com/tcds/ajax/tcds_tdetail_aadt.asp?offset={offset}&agency_id=295&local_id={local_id}&page_type=&pg={pg}&ajax_time=1639668768124'
    response = requests.get(URL, headers = headers)
    aadt_table = pd.read_html(response.text)[0]
    num_pages = ceil(int(aadt_table.iloc[7,0].split()[2]) / 5)
    for pg in range(1,num_pages +1):
        URL = f'https://tdot.public.ms2soft.com/tcds/ajax/tcds_tdetail_aadt.asp?offset={offset}&agency_id=295&local_id={local_id}&page_type=&pg={pg}&ajax_time=1639668768124'
        response = requests.get(URL, headers = headers)
        aadt_page = pd.read_html(response.text)[0]
        aadt_page['loc_id'] = local_id
        aadt_page = aadt_page.iloc[2:-1].drop(0, axis = 1)
        cheatham.append(aadt_page)
    if offset %10 == 9:
        cheatham_list = pd.concat(cheatham)
        cheatham_list.to_csv(f'../cheatham_lists/cheatham_list{str(int((offset + 1) / 10)).zfill(3)}.csv' , index = False)
        cheatham = []
cheatham_list = pd.concat(cheatham)
cheatham_list.to_csv(f'../cheatham_lists/cheatham_list{str(ceil((offset + 1) / 10)).zfill(3)}.csv' , index = False)
cheatham = []
# Out:
#   0%|          | 0/33 [00:00<?, ?it/s]

# %%
str(int((19 + 1) / 10)).zfill(3)
# Out:
# '002'

# %%
pd.concat(for file in glob.glob('../cheatham_lists/*.csv'))
# Out:
# ['../cheatham_lists\\cheatham_list004.csv',
#  '../cheatham_lists\\cheatham_list1.0.csv',
#  '../cheatham_lists\\cheatham_list2.0.csv',
#  '../cheatham_lists\\cheatham_list3.0.csv']

# %%
cheatham_aadt = pd.concat([pd.read_csv(file) for file in glob.glob('../cheatham_lists/*.csv')])

# %%
cheatham_aadt
# Out:
#         1      2      3     4     5            6         7   8    loc_id
# 0    2020   6558  603.0   9.0  65.0  6,058 (92%)  500 (8%) NaN  11000028
# 1    2019   6325    NaN  12.0  65.0          NaN       NaN NaN  11000028
# 2    2018   6475    NaN  10.0  65.0          NaN       NaN NaN  11000028
# 3    2017  58452    NaN   NaN   NaN          NaN       NaN NaN  11000028
# 4    2016   5788    NaN  10.0  65.0          NaN       NaN NaN  11000028
# ..    ...    ...    ...   ...   ...          ...       ...  ..       ...
# 355  1989   6586    NaN   NaN   NaN          NaN       NaN NaN  11000027
# 356  1988   6856    NaN   NaN   NaN          NaN       NaN NaN  11000027
# 357  1987   5910    NaN   NaN   NaN          NaN       NaN NaN  11000027
# 358  1986   6080    NaN   NaN   NaN          NaN       NaN NaN  11000027
# 359  1985   4957    NaN   NaN   NaN          NaN       NaN NaN  11000027
#
# [1012 rows x 9 columns]

# %%
cheatham_list
# Out:
#        1      2    3    4    5          6        7    8    loc_id
# 2   2020    995   90    9   65  959 (96%)  36 (4%)  NaN  11000016
# 3   2019    969  NaN   12   65        NaN      NaN  NaN  11000016
# 4   2018   1103  NaN    9   65        NaN      NaN  NaN  11000016
# 5   2017  10182  NaN  NaN  NaN        NaN      NaN  NaN  11000016
# 6   2016  10112  NaN  NaN  NaN        NaN      NaN  NaN  11000016
# ..   ...    ...  ...  ...  ...        ...      ...  ...       ...
# 3   1989   6586  NaN  NaN  NaN        NaN      NaN  NaN  11000027
# 4   1988   6856  NaN  NaN  NaN        NaN      NaN  NaN  11000027
# 5   1987   5910  NaN  NaN  NaN        NaN      NaN  NaN  11000027
# 6   1986   6080  NaN  NaN  NaN        NaN      NaN  NaN  11000027
# 2   1985   4957  NaN  NaN  NaN        NaN      NaN  NaN  11000027
#
# [360 rows x 9 columns]

# %%
pd.concat(cheatham)
# Out:
#        1      2    3    4    5            6         7    8     loc_id
# 2   2020   5212  504   10   65  4,950 (95%)  262 (5%)  NaN   11000001
# 3   2019   6493  NaN   13   65          NaN       NaN  NaN   11000001
# 4   2018  55582  NaN  NaN  NaN          NaN       NaN  NaN   11000001
# 5   2017   5488  NaN   10   65          NaN       NaN  NaN   11000001
# 6   2016   5300  NaN  NaN  NaN  5,168 (98%)  131 (2%)  NaN   11000001
# ..   ...    ...  ...  ...  ...          ...       ...  ...        ...
# 6   2011   4536  NaN   14  100          NaN       NaN  NaN  11000002R
# 2   2010   4492  NaN   14  100          NaN       NaN  NaN  11000002R
# 3   2009   4474  NaN   14  100          NaN       NaN  NaN  11000002R
# 4   2008   4868  NaN   14  100          NaN       NaN  NaN  11000002R
# 5   2007   4927  NaN   14  100          NaN       NaN  NaN  11000002R
#
# [64 rows x 9 columns]

# %%
pd.DataFrame.drop?

# %%
cheatham[0].iloc[2:-1].drop(0, axis =1)
# Out:
#       1      2    3    4    5            6         7    8    loc_id
# 2  2020   5212  504   10   65  4,950 (95%)  262 (5%)  NaN  11000001
# 3  2019   6493  NaN   13   65          NaN       NaN  NaN  11000001
# 4  2018  55582  NaN  NaN  NaN          NaN       NaN  NaN  11000001
# 5  2017   5488  NaN   10   65          NaN       NaN  NaN  11000001
# 6  2016   5300  NaN  NaN  NaN  5,168 (98%)  131 (2%)  NaN  11000001

# %%
for page in cheatham:
    r = requests.get(URL + str(cheatham), headers = headers)
    print(url)

#     local_id = pd.read_html(r.text)[7].loc[0,1]
#     pie.append(local_id)
# Out:
# 1
# 2
# 3
# 4
# 5
# 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-ff5c1e6cae88> in <module>
#       1 for url in cheatham:
# ----> 2     r = requests.get(URL + str(cheatham), headers = headers)
#       3     print(url)
#       4
#       5 #     local_id = pd.read_html(r.text)[7].loc[0,1]
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ...

# %%
view = pd.read_html(r.text)[7].loc[0,1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-426e0a70a79b> in <module>
# ----> 1 view = pd.read_html(r.text)[7].loc[0,1]
#
# IndexError: list index out of range

# %%
r = requests.get(URL, headers = headers)
local_id = pd.read_html(r.text)[7].loc[0,1]
local_id

# %%
print(URL)

# %%
re.findall('offset=(\d)', URL)

# %%
URL = 'https://tdot.public.ms2soft.com/tcds/tdetail.asp?offset='

# %%
pls_work = []

# %%
bedford

# %% [markdown]
# local_id = '19000001R'
# offset = 1
# pg = 5
#
# URL = f'https://tdot.public.ms2soft.com/tcds/ajax/tcds_tdetail_aadt.asp?offset={offset}&agency_id=295&local_id={local_id}&page_type=&pg={pg}&ajax_time=1639668768124'

# %% [markdown]
# response = requests.get(URL, headers = headers)

# %% [markdown]
# pd.read_html(response.text)[0]

# %% [markdown]
# x = 10
#
# f'this an an f-string with x = {x}'
