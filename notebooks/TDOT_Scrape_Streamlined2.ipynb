# %%
import pandas as pd
import requests
import datetime
from bs4 import BeautifulSoup
import re
from math import ceil
from tqdm.notebook import tqdm

# %%
x = 10

f'this an an f-string with x = {x}'
# Out:
# 'this an an f-string with x = 10'

# %%
local_id = '19000001R'
offset = 1
pg = 5

URL = f'https://tdot.public.ms2soft.com/tcds/ajax/tcds_tdetail_aadt.asp?offset={offset}&agency_id=295&local_id={local_id}&page_type=&pg={pg}&ajax_time=1639668768124'

# %%
headers = {'cookie': 'searchTab=0; MS2Session=engrs3ed2kopropbdodiwahj; __utmc=1; __utmz=1.1639665623.1.1.utmcsr=(direct)|utmccn=(direct)|utmcmd=(none); MS2Session_TMS=kqnj0onh03gdrdlcurwfog05; __utma=1.1684434340.1639665623.1639665623.1639668451.2; __utmt=1; __utmb=1.2.10.1639668451'}

# %%
response = requests.get(URL, headers = headers)

# %%
pd.read_html(response.text)[0]
# Out:
#                                                    0  \
# 0  AADT  AADT Calculation  AADT = VOL x SF x AF A...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                        21-25 of 30
#
#                                                    1  \
# 0  AADT  AADT Calculation  AADT = VOL x SF x AF A...
# 1                                               Year
# 2                                               2000
# 3                                               1999
# 4                                               1998
# 5                                               1997
# 6                                               1996
# 7                                        21-25 of 30
#
#                                                    2  \
# 0  AADT  AADT Calculation  AADT = VOL x SF x AF A...
# 1                                               AADT
# 2                                               1943
# 3                                               2084
# 4                                               2108
# 5                                               2232
# 6                                               2108
# 7                                        21-25 of 30
#
#                                                    3  \
# 0  AADT  AADT Calculation  AADT = VOL x SF x AF A...
# 1                                             DHV-30
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                        21-25 of 30
#
#                                                    4  \
# 0  AADT  AADT Calculation  AADT = VOL x SF x AF A...
# 1                                                K %
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                        21-25 of 30
#
#                                                    5  \
# 0  AADT  AADT Calculation  AADT = VOL x SF x AF A...
# 1                                                D %
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                        21-25 of 30
#
#                                                    6  \
# 0  AADT  AADT Calculation  AADT = VOL x SF x AF A...
# 1                                                 PA
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                        21-25 of 30
#
#                                                    7  \
# 0  AADT  AADT Calculation  AADT = VOL x SF x AF A...
# 1                                                 BC
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                        21-25 of 30
#
#                                                    8
# 0  AADT  AADT Calculation  AADT = VOL x SF x AF A...
# 1                                                Src
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                        21-25 of 30

# %%
# Get the local_id for a given offset
offset = 100

URL = f'https://tdot.public.ms2soft.com/tcds/tdetail.asp?offset={offset}'

response = requests.get(URL, headers = headers)

local_id = pd.read_html(response.text)[7].loc[0,1]

# Code to grab lat/lng probably using BeautifulSoup

# Get the first page of results
pg = 1

URL = f'https://tdot.public.ms2soft.com/tcds/ajax/tcds_tdetail_aadt.asp?offset={offset}&agency_id=295&local_id={local_id}&page_type=&pg={pg}&ajax_time=1639668768124'

response = requests.get(URL, headers = headers)
pd.read_html(response.text)[0]

## Code here to iterate through all of the pages and likely export the results
# Out:
#                                                    0  \
# 0  AADT  AADT Calculation  AADT = VOL x SF x AF A...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
#
#                                                    1  \
# 0  AADT  AADT Calculation  AADT = VOL x SF x AF A...
# 1                                               Year
# 2                                               2020
# 3                                               2019
#
#                                                    2  \
# 0  AADT  AADT Calculation  AADT = VOL x SF x AF A...
# 1                                               AADT
# 2                                               3661
# 3                                               4647
#
#                                                    3  \
# 0  AADT  AADT Calculation  AADT = VOL x SF x AF A...
# 1                                             DHV-30
# 2                                                413
# 3                                                NaN
#
#                                                    4  \
# 0  AADT  AADT Calculation  AADT = VOL x SF x AF A...
# 1                                                K %
# 2                                                 11
# 3                                                NaN
#
#                                                    5  \
# 0  AADT  AADT Calculation  AADT = VOL x SF x AF A...
# 1                                                D %
# 2                                                NaN
# 3                                                NaN
#
#                                                    6  \
# 0  AADT  AADT Calculation  AADT = VOL x SF x AF A...
# 1                                                 PA
# 2                                                NaN
# 3                                                NaN
#
#                                                    7  \
# 0  AADT  AADT Calculation  AADT = VOL x SF x AF A...
# 1                                                 BC
# 2                                                NaN
# 3                                                NaN
#
#                                                    8
# 0  AADT  AADT Calculation  AADT = VOL x SF x AF A...
# 1                                                Src
# 2                                                NaN
# 3                                                NaN
